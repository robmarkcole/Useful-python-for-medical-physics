# %%
ls
# Out:
# Case1_AAA.txt*
# Case6_Dm.txt*
# DVH.csv
# Metrics.csv
# Parse Eclipse DVH text file v1 24-11-2016.ipynb
# __pycache__/
# pyEclipseDVH.py
# test of pyEclipseDVH.py.ipynb

# %%
file = 'Case1_AAA.txt'

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pyEclipseDVH import eclipse_DVH

# %%
Case1_AAA = eclipse_DVH('Case1_AAA.txt')
# Out:
# Case1_AAA.txt loaded 	 patID = Case1_AAA	 Prescription [Gy] = 65.000

# %%
Case1_AAA.DVH_df.head()
# Out:
#          Pseudo Other_P  Pseudo Oral Cav_  Pseudo Midline_P  PTV2 edit_P  \
# Dose_Gy
# 0.000             100.0             100.0             100.0        100.0
# 0.065             100.0             100.0             100.0        100.0
# 0.130             100.0             100.0             100.0        100.0
# 0.195             100.0             100.0             100.0        100.0
# 0.260             100.0             100.0             100.0        100.0
#
#          PTV2_P  PTV1 edit_P    PTV1_P  Lt Par edit_P    Body_P  \
# Dose_Gy
# 0.000     100.0        100.0  100.0000          100.0  100.0000
# 0.065     100.0        100.0   99.9897          100.0   99.9999
# 0.130     100.0        100.0   99.9876          100.0   99.8369
# 0.195     100.0        100.0   99.9856          100.0   99.2374
# 0.260     100.0        100.0   99.9836          100.0   98.5017
#
#          Annulus High_P   ...     SC + 3mm_P  SC + 5mm_P  Pseudo PTV1_P  \
# Dose_Gy                   ...
# ...

# %%
Case1_AAA.DVH_df.plot(legend=False)

# %%
file2 = 'Case6_Dm.txt'

# %%
Case6_Dm = eclipse_DVH(file2)
# Out:
# Case6_Dm.txt loaded 	 patID = Case6_Dm	 Prescription [Gy] = 65.010

# %%
Case6_Dm.metrics_df.head()
# Out:
#                  Rt Par edit_P5  Pseudo ring_P1  Pseudo Oral Cav5  \
# Metric
# Structure        Rt Par edit_P5  Pseudo ring_P1  Pseudo Oral Cav5
# Approval Status      Unapproved      Unapproved        Unapproved
# Plan                   Case6_Dm        Case6_Dm          Case6_Dm
# Course                        1               1                 1
# Volume [cm³]               27.7           657.1             137.6
#
#                  Pseudo Midline_5  PTV2 edit_P5     PTV2_P5  Right Couch Bar1  \
# Metric
# Structure        Pseudo Midline_5  PTV2 edit_P5     PTV2_P5  Right Couch Bar1
# Approval Status        Unapproved    Unapproved  Unapproved        Unapproved
# Plan                     Case6_Dm      Case6_Dm    Case6_Dm          Case6_Dm
# Course                          1             1           1                 1
# Volume [cm³]                 30.6         152.8       159.4             408.6
#
#                  ARTEFACT_P2  65gy cooler_P  PTV1 edit_P5      ...       \
# ...

# %%
Case6_Dm.DVH_df.plot(legend=False)
