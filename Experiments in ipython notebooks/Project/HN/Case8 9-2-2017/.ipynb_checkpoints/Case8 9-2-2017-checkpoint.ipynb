# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pyEclipseDVH import eclipse_DVH
from scipy import interpolate

def get_Dmetric(df, metric_pct):   # for D50% pass 50
    indexes = np.array(df.index)   # get test data index and values
    values = np.array(df.values)
    f = interpolate.interp1d(values, indexes)  # create the interp object
    return f(metric_pct)

def get_HI(df):   # for D50% pass 50
    indexes = np.array(df.index)   # get test data index and values
    values = np.array(df.values)
    f = interpolate.interp1d(values, indexes)  # create the interp object
    HI = (f(2.0) - f(98.0))/f(50.0)
    return HI

# %%
AAA = eclipse_DVH('Case8_AAA.txt')
AXB = eclipse_DVH('Case8_Dm.txt')
# Out:
# Case8_AAA.txt loaded 	 patID = Case8_AAA	 Prescription [Gy] = 65.010
# Case8_Dm.txt loaded 	 patID = Case8_Dm	 Prescription [Gy] = 65.010

# %%
AXB.DVH_df.columns
# Out:
# Index(['Pseudo Oral Cav7', 'Pseudo Midline_7', 'PTV2 edit_P7', 'PTV2_P7',
#        'PTV1 edit_P7', 'Pseudo PTV2_P7', 'Left Couch Bar_3',
#        'Right Couch Bar3', 'artefact_P3', 'Pseudo Ring_P2', 'both ptvs_P2',
#        'PTV1_P7', 'Lt Par edit_P7', 'BS + 5mm_P7', 'BS + 3mm_P6', 'BODY_P7',
#        'R Lens_P7', 'L Lens_P7', 'R Orbit_P7', 'L Orbit_P7', 'Brain Stem_P7',
#        'Spinal Cord_P7', 'R Parotid_P7', 'L Parotid_P7', 'CTV54_P3',
#        'CTV65_P6', 'GTVn + 10_P', 'GTV + 15_P', 'GTV_P4', 'GTVn_P1',
#        'Pseudo Post_P6', 'Rt Par edit_P7', 'SC + 3mm_P7', 'SC + 5mm_P7',
#        'Pseudo PTV1_P7'],
#       dtype='object')

# %%
width=7
height=4
plt.figure(figsize=(width, height))

structure = 'PTV1_P7'
plt.plot(AAA.DVH_df[structure], label="PTV1 AAA", color='b', ls='--')
plt.plot(AXB.DVH_df[structure], label="PTV1 AXB",  color='r' )

structure = 'PTV2_P7'
plt.plot(AAA.DVH_df[structure], label="PTV2 AAA", color='g', ls='--')
plt.plot(AXB.DVH_df[structure], label="PTV2 AXB",  color='k' )

plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.title('Case 8 comparison of AAA and AXB DVH')
plt.xlabel('Dose (Gy)')
plt.ylabel('Ratio of total structure volume (%)')
plt.ylim([0,105])
plt.xlim([50,75])
# Out:
# (50, 75)

# %%
Comparison_df = pd.concat([ AAA.metrics_df['PTV1_P7'], 
                            AXB.metrics_df['PTV1_P7'], 
                           
                           AAA.metrics_df['PTV2_P7'], 
                           AXB.metrics_df['PTV2_P7']], 
                           axis=1)
Comparison_df
# Out:
#                        PTV1_P7     PTV1_P7     PTV2_P7     PTV2_P7
# Metric
# Structure              PTV1_P7     PTV1_P7     PTV2_P7     PTV2_P7
# Approval Status     Unapproved  Unapproved  Unapproved  Unapproved
# Plan                 Case8_AAA    Case8_Dm   Case8_AAA    Case8_Dm
# Course                       1           1           1           1
# Volume [cmÂ³]            369.6       369.6       365.4       365.4
# Dose Cover.[%]           100.0       100.0       100.0       100.0
# Sampling Cover.[%]       100.0       100.0       100.0       100.0
# Min Dose [%]               4.9         3.5         0.5         0.0
# Max Dose [%]             111.8       113.1       109.6       110.4
# Mean Dose [%]            103.1       102.7        86.6        86.4
# Modal Dose [%]           104.9       103.0        87.6        86.3
# Median Dose [%]          104.8       103.7        87.2        86.4
# STD [%]                    8.2         6.3         8.2         6.9
