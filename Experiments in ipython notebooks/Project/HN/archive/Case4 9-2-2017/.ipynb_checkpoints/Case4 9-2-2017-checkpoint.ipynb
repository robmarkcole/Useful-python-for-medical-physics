# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pyEclipseDVH import eclipse_DVH
from scipy import interpolate

def get_Dmetric(df, metric_pct):   # for D50% pass 50
    indexes = np.array(df.index)   # get test data index and values
    values = np.array(df.values)
    f = interpolate.interp1d(values, indexes)  # create the interp object
    return f(metric_pct)

def get_HI(df):   # for D50% pass 50
    indexes = np.array(df.index)   # get test data index and values
    values = np.array(df.values)
    f = interpolate.interp1d(values, indexes)  # create the interp object
    HI = (f(2.0) - f(98.0))/f(50.0)
    return HI

# %%
AAA = eclipse_DVH('Case4_AAA.txt')
AXB = eclipse_DVH('Case4_Dm.txt')
# Out:
# Case4_AAA.txt loaded 	 patID = Case4_AAA	 Prescription [Gy] = 65.010
# Case4_Dm.txt loaded 	 patID = Case4_AXB_Dm	 Prescription [Gy] = 65.010

# %%
AXB.DVH_df.columns
# Out:
# Index(['PTV2_P3', 'Pseudo Midline_3', 'Pseudo Other_P3', 'Lt Par edit_P3',
#        'PTV1 edit_P3', 'PTV2 edit_P3', 'Pseudo hot_P', 'SC + 3mm_P3',
#        'PTV1_P3', 'Body_P3', 'R Parotid_P3', 'BS + 5mm_P3', 'BS + 3mm_P2',
#        'Pseudo Rt paroti', 'R Lens_P3', 'R Optic Nerve_P2', 'L Optic Nerve_P2',
#        'L Orbit_P3', 'Brain Stem_P3', 'level5_P', 'CTV nodes54_P',
#        'GTV Rnode2_P', 'GTV Rnode_P', 'Spinal Cord_P3', 'L Parotid_P3',
#        'CTV65_P2', 'R Orbit_P3', 'Optic Chiasm_P2', 'L Lens_P3', 'GTV Lnode_P',
#        'Pseudo Lt Paroti', 'PTV1+PTV2edit_P', 'Pseudo Ring_P',
#        'Rt Par edit_P3', 'SC + 5mm_P3', 'Pseudo PTV2_P3', 'Pseudo PTV1_P3',
#        'artefact_P'],
#       dtype='object')

# %%
width=7
height=4
plt.figure(figsize=(width, height))

structure = 'PTV1_P3'
plt.plot(AAA.DVH_df[structure], label="PTV1 AAA", color='b', ls='--')
plt.plot(AXB.DVH_df[structure], label="PTV1 AXB",  color='r' )

structure = 'PTV2_P3'
plt.plot(AAA.DVH_df[structure], label="PTV2 AAA", color='g', ls='--')
plt.plot(AXB.DVH_df[structure], label="PTV2 AXB",  color='k' )

plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.title('Case 1 comparison of AAA and AXB DVH')
plt.xlabel('Dose (Gy)')
plt.ylabel('Ratio of total structure volume (%)')
plt.ylim([0,105])
plt.xlim([70,115])
# Out:
# (70, 115)

# %%
Comparison_df = pd.concat([ AAA.metrics_df['PTV1_P3'], 
                            AXB.metrics_df['PTV1_P3'], 
                           
                           AAA.metrics_df['PTV2_P3'], 
                           AXB.metrics_df['PTV2_P3']], 
                           axis=1)
Comparison_df
# Out:
#                        PTV1_P3       PTV1_P3     PTV2_P3       PTV2_P3
# Metric
# Structure              PTV1_P3       PTV1_P3     PTV2_P3       PTV2_P3
# Approval Status     Unapproved    Unapproved  Unapproved    Unapproved
# Plan                 Case4_AAA  Case4_AXB_Dm   Case4_AAA  Case4_AXB_Dm
# Course                       1             1           1             1
# Volume [cmÂ³]            296.7         296.7       189.9         189.9
# Dose Cover.[%]           100.0         100.0       100.0         100.0
# Sampling Cover.[%]       100.0         100.0       100.0         100.0
# Min Dose [Gy]           33.603        40.682       0.015         0.000
# Max Dose [Gy]           72.920        73.835      71.810        73.166
# Mean Dose [Gy]          68.295        67.709      57.240        57.097
# Modal Dose [Gy]         68.735        67.479      56.826        56.222
# Median Dose [Gy]        68.389        67.734      56.809        56.428
# STD [Gy]                 1.276         1.341       5.340         4.794
