# %%
import os
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pyEclipseDVH_v2 import List_txt, Load_patient, get_dmin, get_dmax, get_d_metric, Load_files_to_df

from scipy import interpolate
from scipy import stats
from scipy.stats import wilcoxon  # must import explicitly
import seaborn as sns
import re

# %%
files = List_txt()
files
# Out:
# ['Case10_AAA.txt', 'Case10_AXB.txt']

# %%
df = Load_files_to_df(files)
# Out:
# Case10_AAA.txt loaded 	 patID:AAA PlanID:AAA and number of structures is 38
# Case10_AXB.txt loaded 	 patID:AXB PlanID:AXB and number of structures is 38

# %%
df.head()
# Out:
# patID          AAA                                                       \
# planID         AAA
# Structure CTV65_P8 CTV60_P1 CTV54_P5 Spinal Cord_P9 L Lens_P9 R Lens_P9
# Dose (Gy)
# 0.00         100.0    100.0    100.0          100.0     100.0     100.0
# 0.05         100.0    100.0    100.0          100.0     100.0     100.0
# 0.10         100.0    100.0    100.0          100.0     100.0     100.0
# 0.15         100.0    100.0    100.0          100.0     100.0     100.0
# 0.20         100.0    100.0    100.0          100.0     100.0     100.0
#
# patID                                                                  \
# planID
# Structure L Optic Nerve_P6 R Optic Nerve_P6 L Parotid_P9 R Parotid_P9
# Dose (Gy)
# 0.00                 100.0            100.0        100.0        100.0
# 0.05                 100.0            100.0        100.0        100.0
# 0.10                 100.0            100.0        100.0        100.0
# 0.15                 100.0            100.0        100.0        100.0
# 0.20                 100.0            100.0        100.0        100.0
#
# patID           ...                   AXB                          \
# planID          ...                   AXB
# Structure       ...        Rt Par edit_P9 SC + 3mm_P9 SC + 5mm_P9
# Dose (Gy)       ...
# 0.00            ...                 100.0       100.0       100.0
# 0.05            ...                 100.0       100.0       100.0
# 0.10            ...                 100.0       100.0       100.0
# 0.15            ...                 100.0       100.0       100.0
# 0.20            ...                 100.0       100.0       100.0
#
# patID                                                              \
# planID
# Structure Pseudo PTV1_P9 Pseudo PTV2_P9 Pseudo PTV3_P schotspot_P
# Dose (Gy)
# 0.00               100.0          100.0         100.0       100.0
# 0.05               100.0          100.0         100.0       100.0
# 0.10               100.0          100.0         100.0       100.0
# 0.15               100.0          100.0         100.0       100.0
# 0.20               100.0          100.0         100.0       100.0
#
# patID
# planID
# Structure L Parotid hot_P Pseudo 65 boost_ Pseudo 60 boost_
# Dose (Gy)
# 0.00                100.0            100.0            100.0
# 0.05                100.0            100.0            100.0
# 0.10                100.0            100.0            100.0
# 0.15                100.0            100.0            100.0
# 0.20                100.0            100.0            100.0
#
# [5 rows x 76 columns]

# %%
structures_ls = df.columns.levels[2]
structures_ls
# Out:
# Index(['BS + 3mm_P7', 'BS + 5mm_P8', 'Body_P9', 'Brain Stem_P9', 'CTV54_P5',
#        'CTV60_P1', 'CTV65_P8', 'L Lens_P9', 'L Optic Nerve_P6', 'L Orbit_P9',
#        'L Parotid hot_P', 'L Parotid_P9', 'Lt Par edit_P9', 'Optic Chiasm_P5',
#        'PTV1 edit_P9', 'PTV1_P9', 'PTV2 edit_P9', 'PTV2_P9', 'PTV3 edit_P',
#        'PTV3_P', 'Pseudo 60 boost_', 'Pseudo 65 boost_', 'Pseudo Midline_9',
#        'Pseudo Oral Cav9', 'Pseudo Other_P7', 'Pseudo PTV1_P9',
#        'Pseudo PTV2_P9', 'Pseudo PTV3_P', 'Pseudo Post_P8', 'R Lens_P9',
#        'R Optic Nerve_P6', 'R Orbit_P9', 'R Parotid_P9', 'Rt Par edit_P9',
#        'SC + 3mm_P9', 'SC + 5mm_P9', 'Spinal Cord_P9', 'schotspot_P'],
#       dtype='object', name='Structure')

# %%
PTV1 = structures_ls[15]
PTV1    # string key for this structure
# Out:
# 'PTV1_P9'

# %%
height=6
width=12           # wwidth of figs

df.xs(PTV1, level='Structure', axis=1).plot(figsize=(width, height))

plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
#plt.legend()
#plt.ylim([0,105])
plt.axhline(y=50, c='k', ls = '--')
plt.xlim([62,68])
# Out:
# (62, 68)

# %%
df.plot()
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %% [markdown]
# # Compare the plan metrics exported from Eclipse and parsed via DVHmetrics shiny app
#
# http://seaborn.pydata.org/examples/color_palettes.html

# %%
df = pd.read_csv('DVH_metrics.csv')

# %%
df.head()
# Out:
#     observed  metric       structure  patID
# 0  36.665640   DMEAN  Spinal Cord_P9  AAA_1
# 1  41.811495    D1CC  Spinal Cord_P9  AAA_1
# 2  43.843632  D0.1CC  Spinal Cord_P9  AAA_1
# 3  36.806388    D50%  Spinal Cord_P9  AAA_1
# 4  41.500545     D5%  Spinal Cord_P9  AAA_1

# %%
metrics = df['metric'].unique()
print(len(metrics))
metrics
# Out:
# 8
# array(['DMEAN', 'D1CC', 'D0.1CC', 'D50%', 'D5%', 'D95%', 'DMIN', 'DMAX'], dtype=object)

# %%
df['structure'].unique()
# Out:
# array(['Spinal Cord_P9', 'L Parotid_P9', 'R Parotid_P9', 'Brain Stem_P9',
#        'Body_P9', 'PTV1_P9', 'PTV2_P9'], dtype=object)

# %% [markdown]
# Lets stip these annoying _P9

# %%
format = lambda x: re.sub('_P9', '', x)   # more reliable than strip
format2 = lambda x: re.sub('_1', '', x)   # more reliable than strip

# %%
df['structure'] = df['structure'].map(format)
df['patID'] = df['patID'].map(format2)

# %%
df['structure'].unique()
# Out:
# array(['Spinal Cord', 'L Parotid', 'R Parotid', 'Brain Stem', 'Body',
#        'PTV1', 'PTV2'], dtype=object)

# %%
df[df['patID'] == 'AAA'].head()
# Out:
#     observed  metric    structure patID
# 0  36.665640   DMEAN  Spinal Cord   AAA
# 1  41.811495    D1CC  Spinal Cord   AAA
# 2  43.843632  D0.1CC  Spinal Cord   AAA
# 3  36.806388    D50%  Spinal Cord   AAA
# 4  41.500545     D5%  Spinal Cord   AAA

# %%
df2 = pd.merge(df[df['patID'] == 'AAA'], df[df['patID'] == 'AXB'], how='inner', on=['metric',  'structure'])  # Get merged set

# %%
df2['AXB-AAA'] = df2['observed_y'] - df2['observed_x']

# %%
df2.head()
# Out:
#    observed_x  metric    structure patID_x  observed_y patID_y   AXB-AAA
# 0   36.665640   DMEAN  Spinal Cord     AAA   36.535620     AXB -0.130020
# 1   41.811495    D1CC  Spinal Cord     AAA   41.852497     AXB  0.041002
# 2   43.843632  D0.1CC  Spinal Cord     AAA   43.895051     AXB  0.051418
# 3   36.806388    D50%  Spinal Cord     AAA   36.642124     AXB -0.164265
# 4   41.500545     D5%  Spinal Cord     AAA   41.561710     AXB  0.061166

# %%
diff_data_df2 = df2.pivot(index='structure', columns='metric', values='AXB-AAA')

# %%
sns.heatmap(diff_data_df2, annot=True, linewidths=.5, center=0,  cmap='PRGn') #

# %%
metrics_to_plot = ['D5%', 'D50%', 'D95%']

# Set up the matplotlib figure
height=12
width=8  
palette="Set3"

f, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(width, height), sharex=True)

metric = metrics_to_plot[0]
sns.barplot(x = df2[df2['metric'] == metric]['structure'].values, y = df2[df2['metric'] == metric]['AXB-AAA'].values, palette = palette, ax=ax1)
ax1.set_ylabel(metric)
ax1.set_ylim([-0.5, 0.5])

metric = metrics_to_plot[1]
sns.barplot(x = df2[df2['metric'] == metric]['structure'].values, y = df2[df2['metric'] == metric]['AXB-AAA'].values, palette = palette, ax=ax2)
ax2.set_ylabel(metric)
ax2.set_ylim([-0.5, 0.5])

metric = metrics_to_plot[2]
sns.barplot(x = df2[df2['metric'] == metric]['structure'].values, y = df2[df2['metric'] == metric]['AXB-AAA'].values, palette = palette,ax=ax3)
ax3.set_ylabel(metric)
ax3.set_ylim([-0.5, 0.5])
# Out:
# (-0.5, 0.5)
