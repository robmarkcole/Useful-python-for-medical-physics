# %% [markdown]
# https://github.com/asweigart/pyautogui

# %%
import pyautogui
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
print(pyautogui.size())
# Out:
# (1920, 1080)

# %%
currentMouseX, currentMouseY = pyautogui.position()
currentMouseX
# Out:
# 1270

# %% [markdown]
# ## Automate mouse movements, clicks and interaction boxes

# %%
pyautogui.moveTo(30, 850)
#pyautogui.click()  # need admin rights to block error

# %%
pyautogui.press('esc')

# %%
pyautogui.alert('This is an alert box.')
# Out:
# 'OK'

# %%
pyautogui.confirm('Enter option.', buttons=['A', 'B', 'C'])
# Out:
# 'B'

# %% [markdown]
# ## Take screenshots

# %%
im1 = pyautogui.screenshot()
im1.save('my_screenshot.png')

# %%
plt.imshow(im1)

# %%
img=plt.imread('my_screenshot.png')  # display the file
plt.imshow(img)

# %%
button7location = pyautogui.locateOnScreen('my_screenshot.png')  ## not working?
print(button7location)
# Out:
# None
