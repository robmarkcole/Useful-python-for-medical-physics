# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from scipy.misc import imread   # required for QA track
from scipy.ndimage import gaussian_filter

# %%
ls   # png is lossless so use
# Out:
# Homer.jpg                           py34 image process 22-6-2017.ipynb
# Homer.png

# %% [markdown]
# # Scipy

# %%
data = imread('Homer.png')
red = data[:,:,0]     # data is a numpy array, keep only the red channel
plt.imshow(data);

# %%
homer = {
    "max": np.max(red),
    "min": np.min(red),
    "mean": np.mean(red),
}

# %%
print(float(homer['mean']))
# Out:
# 30.997521901077715

# %%
plt.imshow(gaussian_filter(red, 10), cmap='gray');
