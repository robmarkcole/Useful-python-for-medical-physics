# %%
import pymysql
import pandas as pd

# %%
Connection = pymysql.connect(host='localhost', 
                             user='superuser', 
                             port=3306,
                             password='superuser', 
                             db='db')
   
cursor = Connection.cursor()
query = ("select * from qa_test WHERE calculation_procedure like '%chamber_idx%'")

df_mysql = pd.read_sql(query, Connection)
print('loaded dataframe from MySQL. records:', len(df_mysql))

Connection.close()
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# C:\Users\RCole02\AppData\Local\Continuum\Anaconda3\lib\site-packages\pymysql\connections.py in connect(self, sock)
#     889                             sock = socket.create_connection(
# --> 890                                 (self.host, self.port), self.connect_timeout)
#     891                             break
#
# C:\Users\RCole02\AppData\Local\Continuum\Anaconda3\lib\socket.py in create_connection(address, timeout, source_address)
#     721     if err is not None:
# --> 722         raise err
#     723     else:
#
# C:\Users\RCole02\AppData\Local\Continuum\Anaconda3\lib\socket.py in create_connection(address, timeout, source_address)
#     712                 sock.bind(source_address)
# --> 713             sock.connect(sa)
#     714             return sock
#
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
#
# During handling of the above exception, another exception occurred:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-4-c4903bce24fb> in <module>()
#       3                              port=3306,
#       4                              password='superuser',
# ----> 5                              db='db')
#       6
#       7 cursor = Connection.cursor()
#
# C:\Users\RCole02\AppData\Local\Continuum\Anaconda3\lib\site-packages\pymysql\__init__.py in Connect(*args, **kwargs)
#      88     """
#      89     from .connections import Connection
# ---> 90     return Connection(*args, **kwargs)
#      91
#      92 from pymysql import connections as _orig_conn
#
# C:\Users\RCole02\AppData\Local\Continuum\Anaconda3\lib\site-packages\pymysql\connections.py in __init__(self, host, user, password, database, port, unix_socket, charset, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, ssl, read_default_group, compress, named_pipe, no_delay, autocommit, db, passwd, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout)
#     686             self._sock = None
#     687         else:
# --> 688             self.connect()
#     689
#     690     def _create_ssl_ctx(self, sslp):
#
# C:\Users\RCole02\AppData\Local\Continuum\Anaconda3\lib\site-packages\pymysql\connections.py in connect(self, sock)
#     935                 exc.traceback = traceback.format_exc()
#     936                 if DEBUG: print(exc.traceback)
# --> 937                 raise exc
#     938
#     939             # If e is neither DatabaseError or IOError, It's a bug.
#
# OperationalError: (2003, "Can't connect to MySQL server on 'localhost' ([WinError 10061] No connection could be made because the target machine actively refused it)")

# %%
df_mysql.head()
# Out:
#     id                name                slug  \
# 0  287  EDW Open Prev Mean  edw_open_prev_mean
# 1  341    Prev OP Mean 6MV    prev_op_mean_6mv
# 2  422   Prev OP Mean 10MV   prev_op_mean_10mv
# 3  423   Prev OP Mean 15MV   prev_op_mean_15mv
# 4  424   Prev OP Mean 6MeV   prev_op_mean_6mev
#
#                                          description procedure  category_id  \
# 0  Get previously recorded uncorrected OP mean ba...                     26
# 1  Get previously recorded uncorrected OP mean ba...                     15
# 2  Get previously recorded uncorrected OP mean ba...                     16
# 3  Get previously recorded uncorrected OP mean ba...                     17
# 4  Get previously recorded uncorrected OP mean ba...                     18
#
#         type choices constant_value  \
# 0  composite                   None
# 1  composite                   None
# 2  composite                   None
# 3  composite                   None
# 4  composite                   None
#
#                                calculation_procedure             created  \
# 0  from qatrack.qa.models import TestInstance, Te... 2015-11-06 11:50:37
# 1  from qatrack.qa.models import TestInstance, Te... 2015-11-13 15:49:30
# 2  from qatrack.qa.models import TestInstance, Te... 2015-12-04 13:26:01
# 3  from qatrack.qa.models import TestInstance, Te... 2015-12-04 13:26:11
# 4  from qatrack.qa.models import TestInstance, Te... 2015-12-04 13:26:28
#
#    created_by_id            modified  modified_by_id  chart_visibility  \
# 0              5 2016-08-01 14:19:03               5                 0
# 1              5 2016-07-15 12:45:06               5                 0
# 2              5 2016-07-15 12:44:44               5                 0
# 3              5 2016-07-15 12:44:37               5                 0
# 4              5 2016-07-15 12:44:26               5                 0
#
#    auto_review  display_image
# 0            1              0
# 1            1              0
# 2            1              0
# 3            1              0
# 4            1              0

# %%
df_mysql.to_csv('df_mysql.csv')
