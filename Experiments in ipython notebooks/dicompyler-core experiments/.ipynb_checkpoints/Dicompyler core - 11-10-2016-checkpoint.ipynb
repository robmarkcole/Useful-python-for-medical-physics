# %% [markdown]
# dicompyler-core 0.5.2 has just been released.
#
# It features:
#
# * Added DVH class for Pythonic access to dose volume histogram data.
# * Refactored and added unit tests for dvhcalc.
# * Added examples and usage for dvh and dvhcalc modules.
# * Jupyter notebook of examples can be found in Binder: http://mybinder.org/repo/bastula/dicom-notebooks
#
# The best part of this release is the easy access to DVH data in a Pythonic manner. Check it out!
#
# Cheers,
#
# Adit

# %%
# %matplotlib inline
import os
import numpy as np
import dicom as dicom
from dicompylercore import dicomparser, dvh, dvhcalc
import matplotlib.pyplot as plt
import urllib.request
import os.path

path = os.getcwd()
print(path)
os.listdir(path)
# Out:
# C:\Users\RCole02.ROYALSURREY\Desktop\GitHub\Useful-python-for-medical-physics\Experiments in ipython notebooks\dicompyler-core experiments
# ['-p',
#  '.ipynb_checkpoints',
#  '.rtdose.dcm.icloud',
#  'ct.0.dcm',
#  'Dicompyler core - 11-10-2016.ipynb',
#  'Dicompyler core -test RC.ipynb',
#  'example_data',
#  'rtplan.dcm',
#  'rtss.dcm']

# %%
files = ['rtss.dcm',  'rtdose.dcm']

# %%
rtss_dcm = files[0]
rtdose_dcm = files[1]
rtss = dicomparser.DicomParser(rtss_dcm)
rtdose = dicomparser.DicomParser(rtdose_dcm)

# %%
key = 5
structures = rtss.GetStructures()
structures[key]
# Out:
# {'color': array([255, 128,   0]),
#  'empty': False,
#  'id': 5,
#  'name': 'Heart',
#  'type': 'ORGAN'}

# %%
planes = \
    (np.array(rtdose.ds.GridFrameOffsetVector) \
    * rtdose.ds.ImageOrientationPatient[0]) \
    + rtdose.ds.ImagePositionPatient[2]
dd = rtdose.GetDoseData()

from ipywidgets import FloatSlider, interactive
w = FloatSlider(
    value=0.56,
    min=planes[0],
    max=planes[-1],
    step=np.diff(planes)[0],
    description='Slice Position (mm):',
)

def showdose(z):
    plt.imshow(rtdose.GetDoseGrid(z) * dd['dosegridscaling'],
               vmin=0,
               vmax=dd['dosemax'] * dd['dosegridscaling'])

interactive(showdose, z=w)

# %%
heart = rtdose.GetDVHs()[key]
heart.name = structures[key]['name']
heart.describe()
# Out:
# Structure: Heart
# -----
# DVH Type:  cumulative, abs dose: Gy, abs volume: cm3
# Volume:    437.46 cm3
# Max Dose:  3.10 Gy
# Min Dose:  0.02 Gy
# Mean Dose: 0.64 Gy
# D100:      0.00 Gy
# D98:       0.03 Gy
# D95:       0.03 Gy
# D2cc:      2.93 Gy

# %%
heart.relative_volume.plot()
# Out:
# DVH(cumulative, 311 bins: [0.0:3.1099999999999777] Gy, volume: 100.00000000000048 %, name: 'Heart', rx_dose: 0 Gy)

# %%
lung = rtdose.GetDVHs()[6]
lung.name = structures[6]['name']
lung.rx_dose = 14
lung.plot()
# Out:
# DVH(cumulative, 1274 bins: [0.0:12.739999999999773] Gy, volume: 2008.9485871115003 cm3, name: 'Lt Lung', rx_dose: 14 Gy)

# %%
lung.max
# Out:
# 12.729999999999773

# %%
lung.relative_volume.V5Gy
# Out:
# dvh.DVHValue(2.032438284311445, '%')

# %%
lung.relative_dose().D2cc
# Out:
# dvh.DVHValue(72.285714285713055, '%')

# %%
plt.figure(figsize=(10, 6))
plt.axis([0, 20, 0, 100])
for s in structures.values():
    if not s['empty']:
        dvh.DVH.from_dicom_dvh(rtdose.ds, s['id'], name=s['name']).relative_volume.plot()

# %%
def compare_dvh(key=1):
    structure = rtss.GetStructures()[key]
    orig = dvh.DVH.from_dicom_dvh(rtdose.ds, key, name=structure['name'] + ' Orig')
    calc = dvhcalc.get_dvh(rtss_dcm, rtdose_dcm, key)
    calc.name = structure['name'] + ' Calc'
    orig.compare(calc)

# %%
compare_dvh(key)
