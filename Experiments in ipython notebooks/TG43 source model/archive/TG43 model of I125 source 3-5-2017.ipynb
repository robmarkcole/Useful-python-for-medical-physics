# %% [markdown]
# Implement TG43 calculation of dose proile about an I-125 seed used in LDR brachytherapy from data used by the TPS

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
I125 = {'Conversion_factor':1.270, 
        'Dose_rate_constant':1.018,
       'Anisotropy_constant':0.00,
       'Half_life':59.40,
       'Physical_diameter_cm':0.080,
       'Physical_length_cm':0.450,
       'Active_length_cm':0.381}

# %%
I125['Active_length_cm']
# Out:
# 0.381

# %%
data = pd.read_excel('I125_source_model_RC.xlsx', sheetname=None, index_col=0)   # returns a dict of df

# %%
for key in data:
    print(key)
# Out:
# Radial_dose_function
# Anisotropy_function
# Anisotropy_factors

# %% [markdown]
# ## Explore the data

# %% [markdown]
# ### Radial_dose_function

# %%
r = data['Radial_dose_function'].index.values   # get the radius values
one_on_r_2 = 1/r*2
norm_val = 1.0
one_on_r_2 = one_on_r_2/norm_val
one_on_r_2[0]= 4    # fix the inf value
# Out:
# C:\Users\RCole02.ROYALSURREY\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel\__main__.py:2: RuntimeWarning: divide by zero encountered in true_divide
#   from ipykernel import kernelapp as app

# %%
fit_order = 5
poly_coeffs = np.polyfit(x=data['Radial_dose_function'].index.values, y=data['Radial_dose_function']['Dose_Point'].values, deg=fit_order) # returns the fit coefficients
poly_fit = np.poly1d(poly_coeffs)  # create the fit finction

# %%
plt.plot(data['Radial_dose_function']['Dose_Point'], c='r',  ls='-', label='Point approx')
#plt.plot(data['Radial_dose_function']['Dose_Line'], c='b',  ls='--', label='Line approx')
#plt.plot(r, one_on_r_2, c='g', label='one_on_r_2')
plt.plot(r, poly_fit(r), c='k', ls='--', label='Poly fit')
plt.ylim([0,1.2])

plt.ylabel('Relative dose');
plt.xlabel('R (cm)');
plt.legend();

# %%
len(r)
# Out:
# 24

# %%
data['Anisotropy_function']
# Out:
#          0      1      2      3      5      7      10     12     15     20  \
# r_cm
# 0.25  0.863  0.865  0.865  0.852  0.784  0.861  0.778  0.747  0.833  0.889
# 0.50  0.524  0.517  0.489  0.505  0.668  0.588  0.562  0.570  0.614  0.688
# 1.00  0.423  0.425  0.616  0.681  0.599  0.575  0.579  0.597  0.635  0.698
# 2.00  0.453  0.597  0.701  0.654  0.611  0.603  0.617  0.635  0.668  0.722
# 3.00  0.500  0.675  0.702  0.676  0.637  0.632  0.649  0.668  0.698  0.750
# 5.00  0.564  0.710  0.706  0.682  0.657  0.655  0.672  0.687  0.715  0.761
# 7.00  0.607  0.725  0.720  0.698  0.682  0.682  0.700  0.716  0.741  0.781
#
#      ...     65     70     75     80     85     86     87     88     89  90
# r_cm ...
# 0.25 ...  0.987  0.989  0.990  0.994  0.998  0.996  1.002  1.001  1.001   1
# 0.50 ...  0.998  0.973  0.988  0.994  0.998  1.000  0.998  1.000  1.000   1
# 1.00 ...  0.993  1.005  1.012  0.989  0.998  1.000  1.000  0.998  1.000   1
# 2.00 ...  0.995  1.002  1.012  1.015  0.994  0.996  0.998  1.000  1.000   1
# 3.00 ...  1.005  1.011  1.012  1.018  1.023  1.021  1.001  1.002  1.002   1
# 5.00 ...  0.982  0.995  1.002  1.003  1.011  1.013  1.011  0.999  1.000   1
# 7.00 ...  0.984  0.998  0.997  1.011  1.005  1.006  1.009  1.009  0.999   1
#
# [7 rows x 28 columns]

# %%
import numpy as np
import seaborn as sns
sns.set()

sns.heatmap(1-data['Anisotropy_function'].T)

# %% [markdown]
# Plot the Anisotropy_function at fixed r cm from the seed

# %%
data['Anisotropy_function']
# Out:
#          0      1      2      3      5      7      10     12     15     20  \
# r_cm
# 0.25  0.863  0.865  0.865  0.852  0.784  0.861  0.778  0.747  0.833  0.889
# 0.50  0.524  0.517  0.489  0.505  0.668  0.588  0.562  0.570  0.614  0.688
# 1.00  0.423  0.425  0.616  0.681  0.599  0.575  0.579  0.597  0.635  0.698
# 2.00  0.453  0.597  0.701  0.654  0.611  0.603  0.617  0.635  0.668  0.722
# 3.00  0.500  0.675  0.702  0.676  0.637  0.632  0.649  0.668  0.698  0.750
# 5.00  0.564  0.710  0.706  0.682  0.657  0.655  0.672  0.687  0.715  0.761
# 7.00  0.607  0.725  0.720  0.698  0.682  0.682  0.700  0.716  0.741  0.781
#
#      ...     65     70     75     80     85     86     87     88     89  90
# r_cm ...
# 0.25 ...  0.987  0.989  0.990  0.994  0.998  0.996  1.002  1.001  1.001   1
# 0.50 ...  0.998  0.973  0.988  0.994  0.998  1.000  0.998  1.000  1.000   1
# 1.00 ...  0.993  1.005  1.012  0.989  0.998  1.000  1.000  0.998  1.000   1
# 2.00 ...  0.995  1.002  1.012  1.015  0.994  0.996  0.998  1.000  1.000   1
# 3.00 ...  1.005  1.011  1.012  1.018  1.023  1.021  1.001  1.002  1.002   1
# 5.00 ...  0.982  0.995  1.002  1.003  1.011  1.013  1.011  0.999  1.000   1
# 7.00 ...  0.984  0.998  0.997  1.011  1.005  1.006  1.009  1.009  0.999   1
#
# [7 rows x 28 columns]

# %%
radius_pos = 2
print('At radius of ' + str(data['Anisotropy_function'].index[radius_pos]))
plt.plot(data['Anisotropy_function'].columns.values, data['Anisotropy_function'].iloc[radius_pos].values);
plt.ylabel('Anisotropy_function');
plt.xlabel('Angle (degrees)');
# Out:
# At radius of 1.0

# %% [markdown]
# Plot the Anisotropy_function at an angle of 40 degrees from the seed

# %%
angle = 20
plt.plot(data['Anisotropy_function'][angle]);
plt.xlabel('Radius (cm)')
plt.ylabel('Anisotropy_factor')

# %%
plt.plot(data['Anisotropy_factors'])
