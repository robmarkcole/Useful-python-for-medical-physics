# %% [markdown]
# http://pylinac.readthedocs.io/en/latest/log_analyzer.html

# %%
from pylinac import Dynalog
Dynalog.run_demo()
# Out:
# Results of file: C:\Users\RCole02.ROYALSURREY\AppData\Local\Continuum\Anaconda3\lib\site-packages\pylinac\demo_files\AQA.dlg
# Average RMS of all leaves: 0.037 cm
# Max RMS error of all leaves: 0.076 cm
# 95th percentile error: 0.088 cm
# Number of beam holdoffs: 20
# Gamma pass %: 90.97
# Gamma average: 0.468
