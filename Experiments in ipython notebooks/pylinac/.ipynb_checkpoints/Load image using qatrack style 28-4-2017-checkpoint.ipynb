# %%
ls
# Out:
# Homer.jpg
# Homer.png
# Light to rad analysis/
# Load image using qatrack style 28-4-2017.ipynb
# Log analyser module.ipynb
# Planar imaging module 11-4-2017.ipynb
# flatsym module test.ipynb
# test.png

# %%
# %matplotlib inline
import numpy as np
import scipy as sp
from pylinac.core.image import load, DicomImage, FileImage, ArrayImage  # image,
from PIL import Image

# %%
FILE = open('Homer.jpg', 'rb')    # open and READ BINARY

# %%
img = Image.open(FILE)
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=440x342 at 0x10A10EA58>

# %%
img.size  # the shape of the image
# Out:
# (440, 342)

# %%
np_data = np.array(img.getdata())

# %%
np_data.shape
# Out:
# (150480, 3)

# %%
np_top = np_data[:,0]

# %%
np_top.shape
# Out:
# (150480,)

# %%
np_top_reshaped = np.reshape(np_top, (440, 342))

# %%
plt.imshow(np_top_reshaped);
