# %%
ls
# Out:
# Homer.jpg
# Homer.png
# Light to rad analysis/
# Load image using qatrack style 28-4-2017.ipynb
# Log analyser module.ipynb
# Planar imaging module 11-4-2017.ipynb
# flatsym module test.ipynb
# test.png

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp
from pylinac.core.image import load, DicomImage, FileImage, ArrayImage  # image,
from PIL import Image

# %%
FILE = open('Homer.jpg', 'rb')    # open and READ BINARY

# %%
img = Image.open(FILE)
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=440x342 at 0x10995C7F0>

# %%
img.size  # the shape of the image
# Out:
# (440, 342)

# %%
np_data = np.array(img.getdata())

# %%
plt.imshow(np.reshape(np_data[:,0], (342, 440)));

# %%
from pylinac import LasVegas

# %%
from matplotlib.image import imread
data = imread(FILE)
homer = {"mean": float(data.mean())}
#homer = None

# %%
homer
# Out:
# {'mean': 44.130032783980155}
