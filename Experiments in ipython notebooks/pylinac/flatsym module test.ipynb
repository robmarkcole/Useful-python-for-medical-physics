# %% [markdown]
# http://pylinac.readthedocs.io/en/latest/flatsym.html#flatness-symmetry-module-documentation

# %%
from pylinac.flatsym import BeamImage

import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
pwd
# Out:
# '/Users/robincole/Documents/Github/Useful-python-for-medical-physics/Experiments in ipython notebooks/pylinac'

# %%
my_img = BeamImage()

# %%
# ?my_img

# %%
my_img.run_demo()
