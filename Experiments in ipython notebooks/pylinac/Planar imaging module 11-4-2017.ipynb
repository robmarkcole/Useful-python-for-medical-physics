# %% [markdown]
# http://pylinac.readthedocs.io/en/latest/planar_imaging.html#planar-imaging-module-documentation

# %%
from pylinac.flatsym import BeamImage, Image
# %matplotlib inline

# %%
from pylinac import LeedsTOR

LeedsTOR.run_demo()

# %% [markdown]
# ### In house data

# %%
img_path = 'C:\\path_to.dcm'

# %%
pfimg = Image.load(img_path)

# %%
pfimg.plot()
